# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# %%
model = YOLO('yolo11l.pt')

# %%
class_list = model.names
class_list
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
cap = cv2.VideoCapture('test_videos/4.mp4')

# %%
line_y_red = 430  # Red line position

# %%
class_counts = defaultdict(int)

# %%
crossed_ids = set()

# %%
frame_count = 0

# %%
# Confidence threshold for filtering weak detections
CONFIDENCE_THRESHOLD = 0.5

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes = [1,2,3,5,6,7]) 
    #print(results)

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (690, line_y_red), (1130, line_y_red), (0, 0, 255), 3)
        #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


        

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2            

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 


            # Check if the object has crossed the red line
            if cy > line_y_red and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1


        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    
    
    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)    
    
    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640
1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 226.3ms
# Speed: 1.3ms preprocess, 226.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 209.8ms
# Speed: 1.6ms preprocess, 209.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 208.5ms
# Speed: 1.1ms preprocess, 208.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 204.2ms
# Speed: 1.6ms preprocess, 204.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       4     break
#       6 # Run YOLO tracking on the frame
# ----> 7 results = model.track(frame, persist=True, classes = [1,2,3,5,6,7])
#       8 #print(results)
#       9
#      10 # Ensure results are not empty
#      11 if results[0].boxes.data is not None:
#      12     # Get the detected boxes, their class indices, and track IDs
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/model.py:606, in Model.track(self, source, stream, persist, **kwargs)
#     604 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     605 kwargs["mode"] = "track"
# --> 606 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/model.py:559, in Model.predict(self, source, stream, predictor, **kwargs)
#     557 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     558     self.predictor.set_prompts(prompts)
# --> 559 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:175, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     173     return self.stream_inference(source, model, *args, **kwargs)
#     174 else:
# --> 175     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:261, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     259 # Inference
#     260 with profilers[1]:
# --> 261     preds = self.inference(im, *args, **kwargs)
#     262     if self.args.embed:
#     263         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:145, in BasePredictor.inference(self, im, *args, **kwargs)
#     139 """Runs inference on a given image using the specified model and arguments."""
#     140 visualize = (
#     141     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     142     if self.args.visualize and (not self.source_type.tensor)
#     143     else False
#     144 )
# --> 145 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:555, in AutoBackend.forward(self, im, augment, visualize, embed)
#     553 # PyTorch
#     554 if self.pt or self.nn_module:
# --> 555     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     557 # TorchScript
#     558 elif self.jit:
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:109, in BaseModel.forward(self, x, *args, **kwargs)
#     107 if isinstance(x, dict):  # for cases of training and validating while training.
#     108     return self.loss(x, *args, **kwargs)
# --> 109 return self.predict(x, *args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:127, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     125 if augment:
#     126     return self._predict_augment(x)
# --> 127 return self._predict_once(x, profile, visualize, embed)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/tasks.py:148, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     146 if profile:
#     147     self._profile_one_layer(m, x, dt)
# --> 148 x = m(x)  # run
#     149 y.append(x if m.i in self.save else None)  # save output
#     150 if visualize:
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:239, in C2f.forward(self, x)
#     237 """Forward pass through C2f layer."""
#     238 y = list(self.cv1(x).chunk(2, 1))
# --> 239 y.extend(m(y[-1]) for m in self.m)
#     240 return self.cv2(torch.cat(y, 1))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:239, in <genexpr>(.0)
#     237 """Forward pass through C2f layer."""
#     238 y = list(self.cv1(x).chunk(2, 1))
# --> 239 y.extend(m(y[-1]) for m in self.m)
#     240 return self.cv2(torch.cat(y, 1))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:264, in C3.forward(self, x)
#     262 def forward(self, x):
#     263     """Forward pass through the CSP bottleneck with 2 convolutions."""
# --> 264     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:348, in Bottleneck.forward(self, x)
#     346 def forward(self, x):
#     347     """Applies the YOLO FPN to input data."""
# --> 348     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:55, in Conv.forward_fuse(self, x)
#      53 def forward_fuse(self, x):
#      54     """Apply convolution and activation without batch normalization."""
# ---> 55     return self.act(self.conv(x))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:432, in SiLU.forward(self, input)
#     431 def forward(self, input: Tensor) -> Tensor:
# --> 432     return F.silu(input, inplace=self.inplace)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/nn/functional.py:2379, in silu(input, inplace)
#    2377     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2378 if inplace:
# -> 2379     return torch._C._nn.silu_(input)
#    2380 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
