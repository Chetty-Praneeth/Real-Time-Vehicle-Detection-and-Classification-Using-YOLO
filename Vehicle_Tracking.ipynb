# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# %%
model = YOLO('yolo11l.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l.pt to 'yolo11l.pt'...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 49.0M/49.0M [00:09<00:00, 5.25MB/s]

# %%
class_list = model.names
class_list
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
cap = cv2.VideoCapture('test_videos/4.mp4')

# %%
line_y_red = 430  # Red line position

# %%
class_counts = defaultdict(int)

# %%
crossed_ids = set()

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist=True, classes = [1,2,3,5,6,7]) 
    #print(results)

    # Ensure results are not empty
    if results[0].boxes.data is not None:
        # Get the detected boxes, their class indices, and track IDs
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (690, line_y_red), (1130, line_y_red), (0, 0, 255), 3)
        #cv2.putText(frame, 'Red Line', (690, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)


        

        # Loop through each detected object
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Calculate the center point
            cy = (y1 + y2) // 2            

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            
            cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 


            # Check if the object has crossed the red line
            if cy > line_y_red and track_id not in crossed_ids:
                # Mark the object as crossed
                crossed_ids.add(track_id)
                class_counts[class_name] += 1


        # Display the counts on the frame
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    
    
    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)    
    
    # Exit loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 307.3ms
# Speed: 5.8ms preprocess, 307.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 235.4ms
# Speed: 1.3ms preprocess, 235.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 222.1ms
# Speed: 1.8ms preprocess, 222.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 199.6ms
# Speed: 1.0ms preprocess, 199.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 197.8ms
# Speed: 1.1ms preprocess, 197.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 2025-02-12 00:25:33.171 Python[36313:13492784] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-12 00:25:33.171 Python[36313:13492784] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 209.7ms
# Speed: 1.7ms preprocess, 209.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 200.7ms
# Speed: 1.2ms preprocess, 200.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 motorcycles, 3 buss, 2 trucks, 201.5ms
# Speed: 1.0ms preprocess, 201.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 209.9ms
# Speed: 1.2ms preprocess, 209.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 201.5ms
# Speed: 1.6ms preprocess, 201.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 2 trucks, 196.1ms
# Speed: 1.1ms preprocess, 196.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 201.1ms
# Speed: 1.5ms preprocess, 201.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 203.0ms
# Speed: 1.4ms preprocess, 203.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 195.4ms
# Speed: 1.8ms preprocess, 195.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 196.3ms
# Speed: 1.9ms preprocess, 196.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 199.7ms
# Speed: 1.6ms preprocess, 199.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 190.3ms
# Speed: 1.6ms preprocess, 190.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 204.8ms
# Speed: 1.0ms preprocess, 204.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 194.7ms
# Speed: 1.0ms preprocess, 194.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 198.7ms
# Speed: 1.6ms preprocess, 198.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 199.0ms
# Speed: 1.0ms preprocess, 199.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 198.5ms
# Speed: 1.9ms preprocess, 198.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 194.3ms
# Speed: 1.5ms preprocess, 194.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 200.2ms
# Speed: 1.2ms preprocess, 200.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 207.0ms
# Speed: 1.1ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 221.0ms
# Speed: 2.8ms preprocess, 221.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 204.6ms
# Speed: 1.7ms preprocess, 204.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 207.0ms
# Speed: 1.2ms preprocess, 207.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 195.9ms
# Speed: 1.5ms preprocess, 195.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 202.4ms
# Speed: 1.7ms preprocess, 202.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 200.5ms
# Speed: 1.6ms preprocess, 200.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 197.1ms
# Speed: 1.1ms preprocess, 197.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 197.5ms
# Speed: 1.5ms preprocess, 197.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 206.3ms
# Speed: 1.5ms preprocess, 206.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 204.6ms
# Speed: 1.6ms preprocess, 204.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 196.5ms
# Speed: 1.5ms preprocess, 196.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 197.2ms
# Speed: 1.0ms preprocess, 197.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 198.4ms
# Speed: 1.0ms preprocess, 198.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 195.0ms
# Speed: 1.1ms preprocess, 195.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 209.5ms
# Speed: 1.1ms preprocess, 209.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 202.1ms
# Speed: 1.0ms preprocess, 202.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 319.1ms
# Speed: 1.1ms preprocess, 319.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 196.9ms
# Speed: 1.2ms preprocess, 196.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 4 buss, 197.9ms
# Speed: 1.0ms preprocess, 197.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 4 buss, 211.7ms
# Speed: 1.4ms preprocess, 211.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 4 buss, 237.7ms
# Speed: 1.1ms preprocess, 237.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 208.9ms
# Speed: 2.1ms preprocess, 208.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss,
8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trucks, 233.4ms
# Speed: 2.8ms preprocess, 233.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trucks, 239.1ms
# Speed: 2.2ms preprocess, 239.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 2 trucks, 276.4ms
# Speed: 1.7ms preprocess, 276.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 2 trucks, 236.5ms
# Speed: 3.0ms preprocess, 236.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 2 trucks, 230.5ms
# Speed: 1.9ms preprocess, 230.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trucks, 232.0ms
# Speed: 3.0ms preprocess, 232.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trucks, 231.7ms
# Speed: 3.0ms preprocess, 231.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 buss, 2 trucks, 228.5ms
# Speed: 1.5ms preprocess, 228.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 3 trucks, 236.6ms
# Speed: 2.7ms preprocess, 236.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 3 trucks, 239.7ms
# Speed: 3.7ms preprocess, 239.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 2 buss, 3 trucks, 244.7ms
# Speed: 2.5ms preprocess, 244.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 3 trucks, 250.8ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       4     break
#       6 # Run YOLO tracking on the frame
# ----> 7 results = model.track(frame, persist=True, classes = [1,2,3,5,6,7])
#       8 #print(results)
#       9
#      10 # Ensure results are not empty
#      11 if results[0].boxes.data is not None:
#      12     # Get the detected boxes, their class indices, and track IDs
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/model.py:606, in Model.track(self, source, stream, persist, **kwargs)
#     604 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     605 kwargs["mode"] = "track"
# --> 606 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/model.py:559, in Model.predict(self, source, stream, predictor, **kwargs)
#     557 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     558     self.predictor.set_prompts(prompts)
# --> 559 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:175, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     173     return self.stream_inference(source, model, *args, **kwargs)
#     174 else:
# --> 175     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:285, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     283 # Print batch results
#     284 if self.args.verbose:
# --> 285     LOGGER.info("\n".join(s))
#     287 self.run_callbacks("on_predict_batch_end")
#     288 yield from self.results
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1539, in Logger.info(self, msg, *args, **kwargs)
#    1530 """
#    1531 Log 'msg % args' with severity 'INFO'.
#    1532
#    (...)
#    1536 logger.info("Houston, we have a %s", "notable problem", exc_info=True)
#    1537 """
#    1538 if self.isEnabledFor(INFO):
# -> 1539     self._log(INFO, msg, args, **kwargs)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1684, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1681         exc_info = sys.exc_info()
#    1682 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1683                          exc_info, func, extra, sinfo)
# -> 1684 self.handle(record)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1700, in Logger.handle(self, record)
#    1698 if isinstance(maybe_record, LogRecord):
#    1699     record = maybe_record
# -> 1700 self.callHandlers(record)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1762, in Logger.callHandlers(self, record)
#    1760     found = found + 1
#    1761     if record.levelno >= hdlr.level:
# -> 1762         hdlr.handle(record)
#    1763 if not c.propagate:
#    1764     c = None    #break out
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1028, in Handler.handle(self, record)
#    1026 self.acquire()
#    1027 try:
# -> 1028     self.emit(record)
#    1029 finally:
#    1030     self.release()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1164, in StreamHandler.emit(self, record)
#    1162     # issue 35046: merged two stream.writes into one.
#    1163     stream.write(msg + self.terminator)
# -> 1164     self.flush()
#    1165 except RecursionError:  # See issue 36272
#    1166     raise
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1144, in StreamHandler.flush(self)
#    1142 try:
#    1143     if self.stream and hasattr(self.stream, "flush"):
# -> 1144         self.stream.flush()
#    1145 finally:
#    1146     self.release()
#
# File ~/Documents/myprojects/Real-Time-Object-Detection-and-Tracking-in-a-ROS-Environment/venv/lib/python3.12/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
