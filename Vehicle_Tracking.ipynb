# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# %%
model = YOLO('yolo11l.pt')

# %%
class_list = model.names
class_list
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
cap = cv2.VideoCapture('test_videos/4.mp4')

# %%
line_y_red = 430  # Red line position

# %%
class_counts = defaultdict(int)

# %%
crossed_ids = set()

# %%
frame_count = 0

# %%
# Confidence threshold for filtering weak detections
CONFIDENCE_THRESHOLD = 0.5

# %%
# Speed estimation parameters
PIXEL_TO_METER_RATIO = 0.05  # Example: 1 pixel = 0.05 meters
FRAME_RATE = cap.get(cv2.CAP_PROP_FPS)
prev_positions = {}

# %%
# FPS Calculation
prev_time = 0

# %%
# Ground truth (replace with actual values if available)
y_true = []  # Ground truth labels
y_pred = []  # Model predictions

# %%
import time
import numpy as np
from sklearn.metrics import precision_score, recall_score, accuracy_score,f1_score

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    frame_count += 1

    # FPS calculation
    current_time = time.time()
    fps = 1 / (current_time - prev_time)
    prev_time = current_time

    # YOLO inference with tracking
    results = model.track(frame, persist=True, classes=[1,2,3,5,6,7])

    if results[0].boxes.data is not None:
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidences = results[0].boxes.conf.cpu()

        cv2.line(frame, (690, line_y_red), (1130, line_y_red), (0, 0, 255), 3)

        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidences):
            if conf < CONFIDENCE_THRESHOLD:
                continue  # Skip low-confidence detections

            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2  # Center point
            cy = (y1 + y2) // 2  

            class_name = class_list[class_idx]

            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            cv2.putText(frame, f"ID: {track_id} {class_name} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2) 

            # Track vehicle speed
            if track_id in prev_positions:
                prev_cx, prev_cy = prev_positions[track_id]
                distance_pixels = np.sqrt((cx - prev_cx) ** 2 + (cy - prev_cy) ** 2)
                distance_meters = distance_pixels * PIXEL_TO_METER_RATIO
                speed_mps = distance_meters * FRAME_RATE  # Speed in meters per second
                speed_kph = speed_mps * 3.6  # Convert to km/h

                cv2.putText(frame, f"Speed: {speed_kph:.1f} km/h", (x1, y2 + 20),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

            prev_positions[track_id] = (cx, cy)

            # Vehicle Counting
            if cy > line_y_red and track_id not in crossed_ids:
                crossed_ids.add(track_id)
                class_counts[class_name] += 1
                y_pred.append(class_name)  # Add detected class for evaluation

        # Display vehicle count
        y_offset = 30
        for class_name, count in class_counts.items():
            cv2.putText(frame, f"{class_name}: {count}", (50, y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            y_offset += 30

    # Display FPS
    cv2.putText(frame, f"FPS: {fps:.2f}", (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

    # Show frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Precision & Recall Calculation
if y_true and y_pred:  # Only calculate if ground truth is available
    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    print(f"Precision: {precision:.2f}, Recall: {recall:.2f}")

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 298.9ms
# Speed: 4.5ms preprocess, 298.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 374.6ms
# Speed: 1.7ms preprocess, 374.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 219.9ms
# Speed: 1.2ms preprocess, 219.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 1 truck, 190.3ms
# Speed: 1.2ms preprocess, 190.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 193.2ms
# Speed: 1.4ms preprocess, 193.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 2025-02-14 21:33:43.947 Python[71191:14543291] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-14 21:33:43.947 Python[71191:14543291] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 206.9ms
# Speed: 1.2ms preprocess, 206.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 199.9ms
# Speed: 1.7ms preprocess, 199.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 243.7ms
# Speed: 1.4ms preprocess, 243.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 motorcycles, 3 buss, 2 trucks, 188.6ms
# Speed: 1.4ms preprocess, 188.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 2 trucks, 206.6ms
# Speed: 1.3ms preprocess, 206.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 motorcycles, 3 buss, 1 truck, 248.3ms
# Speed: 1.6ms preprocess, 248.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 motorcycles, 3 buss, 2 trucks, 206.5ms
# Speed: 1.6ms preprocess, 206.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 190.4ms
# Speed: 1.1ms preprocess, 190.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 189.8ms
# Speed: 1.1ms preprocess, 189.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 191.8ms
# Speed: 1.3ms preprocess, 191.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 193.4ms
# Speed: 2.0ms preprocess, 193.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 193.5ms
# Speed: 1.0ms preprocess, 193.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 196.9ms
# Speed: 1.0ms preprocess, 196.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 190.8ms
# Speed: 1.1ms preprocess, 190.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 197.2ms
# Speed: 0.9ms preprocess, 197.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 196.3ms
# Speed: 1.0ms preprocess, 196.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 189.9ms
# Speed: 0.9ms preprocess, 189.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 3 buss, 1 truck, 197.1ms
# Speed: 1.0ms preprocess, 197.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 1 truck, 195.4ms
# Speed: 1.0ms preprocess, 195.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 motorcycles, 3 buss, 196.1ms
# Speed: 1.7ms preprocess, 196.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 189.0ms
# Speed: 1.4ms preprocess, 189.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 185.9ms
# Speed: 1.4ms preprocess, 185.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 188.9ms
# Speed: 0.9ms preprocess, 188.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 222.6ms
# Speed: 1.4ms preprocess, 222.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 1 truck, 195.2ms
# Speed: 1.2ms preprocess, 195.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 236.3ms
# Speed: 1.2ms preprocess, 236.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 191.5ms
# Speed: 1.4ms preprocess, 191.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 192.2ms
# Speed: 1.0ms preprocess, 192.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 196.0ms
# Speed: 1.1ms preprocess, 196.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 motorcycles, 3 buss, 187.8ms
# Speed: 1.0ms preprocess, 187.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 motorcycles, 3 buss, 188.1ms
# Speed: 1.3ms preprocess, 188.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 202.3ms
# Speed: 1.3ms preprocess, 202.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 206.9ms
# Speed: 1.1ms preprocess, 206.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 motorcycles, 3 buss, 188.2ms
# Speed: 1.4ms preprocess, 188.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 202.0ms
# Speed: 1.1ms preprocess, 202.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 195.0ms
# Speed: 1.4ms preprocess, 195.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 4 buss, 197.6ms
# Speed: 1.0ms preprocess, 197.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 191.2ms
# Speed: 1.3ms preprocess, 191.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 186.5ms
# Speed: 1.7ms preprocess, 186.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 4 buss, 191.6ms
# Speed: 1.1ms preprocess, 191.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 4 buss, 225.1ms
# Speed: 1.6ms preprocess, 225.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 motorcycles, 4 buss, 206.9ms
# Speed: 1.2ms preprocess, 206.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 190.5ms
# Speed: 1.1ms preprocess, 190.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 motorcycles, 4 buss, 198.5ms
# Speed: 1.1ms preprocess, 198.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 4 buss, 207.7ms
# Speed: 1.7ms preprocess, 207.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 3 buss, 192.5ms
# Speed: 1.6ms preprocess, 192.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 motorcycles, 2 buss, 190.8ms
# Speed: 0.9ms preprocess, 190.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 186.9ms
# Speed: 1.2ms preprocess, 186.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 191.9ms
# Speed: 1.0ms preprocess, 191.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 197.7ms
# Speed: 1.1ms preprocess, 197.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 199.1ms
# Speed: 1.4ms preprocess, 199.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 195.6ms
# Speed: 1.5ms preprocess, 195.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 193.4ms
# Speed: 1.0ms preprocess, 193.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 202.0ms
# Speed: 1.6ms preprocess, 202.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 1 truck, 199.3ms
# Speed: 1.5ms preprocess, 199.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 199.5ms
# Speed: 1.0ms preprocess, 199.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 1 truck, 193.6ms
# Speed: 1.4ms preprocess, 193.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 2 buss, 1 truck, 191.1ms
# Speed: 1.5ms preprocess, 191.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 3 buss, 187.7ms
# Speed: 1.2ms preprocess, 187.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 3 buss, 189.3ms
# Speed: 1.1ms preprocess, 189.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 2 buss, 208.2ms
# Speed: 1.1ms preprocess, 208.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 2 buss, 200.7ms
# Speed: 1.0ms preprocess, 200.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 196.7ms
# Speed: 1.1ms preprocess, 196.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 204.2ms
# Speed: 1.2ms preprocess, 204.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 211.0ms
# Speed: 1.9ms preprocess, 211.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 216.0ms
# Speed: 1.5ms preprocess, 216.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 1 bus, 1 truck, 203.7ms
# Speed: 1.6ms preprocess, 203.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 204.1ms
# Speed: 1.4ms preprocess, 204.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 206.2ms
# Speed: 5.2ms preprocess, 206.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 199.1ms
# Speed: 1.3ms preprocess, 199.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 197.2ms
# Speed: 1.0ms preprocess, 197.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 2 buss, 191.8ms
# Speed: 1.8ms preprocess, 191.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 187.4ms
# Speed: 1.2ms preprocess, 187.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 184.7ms
# Speed: 1.2ms preprocess, 184.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 2 buss, 187.9ms
# Speed: 1.1ms preprocess, 187.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 motorcycles, 3 buss, 199.8ms
# Speed: 1.1ms preprocess, 199.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 209.8ms
# Speed: 1.0ms preprocess, 209.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 1 truck, 194.2ms
# Speed: 1.3ms preprocess, 194.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 195.6ms
# Speed: 1.4ms preprocess, 195.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 3 buss, 197.6ms
# Speed: 1.1ms preprocess, 197.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 200.8ms
# Speed: 1.2ms preprocess, 200.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 202.6ms
# Speed: 2.0ms preprocess, 202.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 201.8ms
# Speed: 1.2ms preprocess, 201.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 192.6ms
# Speed: 1.0ms preprocess, 192.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 3 buss, 192.0ms
# Speed: 1.1ms preprocess, 192.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 1 truck, 202.7ms
# Speed: 1.3ms preprocess, 202.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 217.7ms
# Speed: 2.0ms preprocess, 217.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 221.9ms
# Speed: 1.4ms preprocess, 221.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 242.1ms
# Speed: 1.5ms preprocess, 242.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 198.7ms
# Speed: 1.4ms preprocess, 198.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 204.9ms
# Speed: 1.5ms preprocess, 204.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 202.1ms
# Speed: 1.5ms preprocess, 202.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 198.6ms
# Speed: 1.1ms preprocess, 198.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 198.7ms
# Speed: 1.1ms preprocess, 198.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 195.5ms
# Speed: 1.1ms preprocess, 195.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 3 buss, 200.9ms
# Speed: 1.5ms preprocess, 200.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 200.5ms
# Speed: 1.7ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 193.9ms
# Speed: 1.5ms preprocess, 193.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 193.4ms
# Speed: 1.7ms preprocess, 193.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 207.0ms
# Speed: 1.4ms preprocess, 207.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 191.5ms
# Speed: 1.0ms preprocess, 191.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 192.9ms
# Speed: 1.5ms preprocess, 192.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 196.9ms
# Speed: 1.1ms preprocess, 196.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 1 truck, 196.0ms
# Speed: 1.4ms preprocess, 196.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 1 bus, 2 trucks, 194.2ms
# Speed: 1.1ms preprocess, 194.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 motorcycles, 1 bus, 2 trucks, 194.7ms
# Speed: 1.3ms preprocess, 194.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 2 buss, 2 trucks, 195.4ms
# Speed: 1.0ms preprocess, 195.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 3 buss, 1 truck, 194.3ms
# Speed: 1.2ms preprocess, 194.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 motorcycles, 3 buss, 1 truck, 202.8ms
# Speed: 1.5ms preprocess, 202.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 motorcycles, 2 buss, 1 truck, 224.5ms
# Speed: 1.2ms preprocess, 224.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 228.0ms
# Speed: 1.3ms preprocess, 228.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 264.7ms
# Speed: 2.1ms preprocess, 264.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 205.7ms
# Speed: 1.7ms preprocess, 205.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 8 motorcycles, 2 buss, 213.5ms
# Speed: 1.2ms preprocess, 213.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 8 motorcycles, 2 buss, 206.1ms
# Speed: 1.2ms preprocess, 206.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 8 motorcycles, 2 buss, 216.7ms
# Speed: 1.5ms preprocess, 216.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 217.0ms
# Speed: 1.8ms preprocess, 217.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 9 motorcycles, 2 buss, 215.1ms
# Speed: 1.7ms preprocess, 215.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 9 motorcycles, 2 buss, 216.8ms
# Speed: 1.5ms preprocess, 216.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 8 motorcycles, 2 buss, 225.1ms
# Speed: 1.3ms preprocess, 225.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 9 motorcycles, 2 buss, 211.8ms
# Speed: 1.2ms preprocess, 211.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 9 motorcycles, 2 buss, 218.9ms
# Speed: 1.4ms preprocess, 218.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 218.1ms
# Speed: 2.4ms preprocess, 218.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 8 motorcycles, 2 buss, 257.0ms
# Speed: 3.8ms preprocess, 257.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 8 motorcycles, 2 buss, 217.7ms
# Speed: 1.6ms preprocess, 217.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 8 motorcycles, 2 buss, 209.3ms
# Speed: 1.4ms preprocess, 209.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 210.1ms
# Speed: 1.2ms preprocess, 210.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 206.0ms
# Speed: 1.7ms preprocess, 206.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 210.3ms
# Speed: 1.3ms preprocess, 210.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 207.7ms
# Speed: 1.8ms preprocess, 207.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 11 motorcycles, 2 buss, 210.4ms
# Speed: 1.4ms preprocess, 210.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 11 motorcycles, 2 buss, 206.8ms
# Speed: 1.2ms preprocess, 206.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 1 truck, 208.4ms
# Speed: 1.5ms preprocess, 208.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 1 truck, 222.8ms
# Speed: 1.4ms preprocess, 222.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 1 truck, 208.8ms
# Speed: 1.2ms preprocess, 208.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 1 bus, 209.8ms
# Speed: 1.1ms preprocess, 209.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 210.5ms
# Speed: 2.2ms preprocess, 210.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 210.4ms
# Speed: 1.1ms preprocess, 210.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 10 motorcycles, 2 buss, 1 truck, 208.7ms
# Speed: 1.4ms preprocess, 208.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 1 truck, 208.8ms
# Speed: 1.6ms preprocess, 208.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 9 motorcycles, 2 buss, 1 truck, 207.2ms
# Speed: 1.4ms preprocess, 207.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 motorcycles, 2 buss, 1 truck, 208.2ms
# Speed: 1.2ms preprocess, 208.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 10 motorcycles, 2 buss, 1 truck, 211.1ms
# Speed: 1.3ms preprocess, 211.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 motorcycles, 2 buss, 1 truck, 210.0ms
# Speed: 1.2ms preprocess, 210.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 motorcycles, 2 buss, 1 truck, 208.7ms
# Speed: 1.5ms preprocess, 208.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 9 motorcycles, 2 buss, 2 trucks, 224.0ms
# Speed: 1.2ms preprocess, 224.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 2 buss, 1 truck, 221.7ms
# Speed: 1.2ms preprocess, 221.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 2 buss, 2 trucks, 220.7ms
# Speed: 1.6ms preprocess, 220.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 1 bus, 1 truck, 218.7ms
# Speed: 1.4ms preprocess, 218.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 9 motorcycles, 2 buss, 217.8ms
# Speed: 1.3ms preprocess, 217.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 10 motorcycles, 2 buss, 211.0ms
# Speed: 1.3ms preprocess, 211.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 2 buss, 208.7ms
# Speed: 1.2ms preprocess, 208.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 9 motorcycles, 2 buss, 213.4ms
# Speed: 1.4ms preprocess, 213.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 8 motorcycles, 2 buss, 1 truck, 208.6ms
# Speed: 1.3ms preprocess, 208.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 1 truck, 218.0ms
# Speed: 1.4ms preprocess, 218.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 2 buss, 1 truck, 220.2ms
# Speed: 1.4ms preprocess, 220.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 1 truck, 218.8ms
# Speed: 1.7ms preprocess, 218.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 1 bus, 2 trucks, 233.3ms
# Speed: 1.4ms preprocess, 233.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 1 truck, 238.8ms
# Speed: 1.7ms preprocess, 238.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 motorcycles, 2 buss, 1 truck, 197.7ms
# Speed: 1.3ms preprocess, 197.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 1 truck, 209.0ms
# Speed: 1.7ms preprocess, 209.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 2 buss, 1 truck, 194.2ms
# Speed: 1.2ms preprocess, 194.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8 motorcycles, 3 buss, 1 truck, 197.5ms
# Speed: 1.4ms preprocess, 197.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 196.5ms
# Speed: 1.2ms preprocess, 196.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 198.2ms
# Speed: 1.1ms preprocess, 198.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 3 buss, 1 truck, 197.0ms
# Speed: 1.2ms preprocess, 197.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 2 buss, 2 trucks, 198.3ms
# Speed: 1.2ms preprocess, 198.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 motorcycles, 1 bus, 4 trucks, 197.6ms
# Speed: 1.7ms preprocess, 197.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 2 buss, 2 trucks, 195.2ms
# Speed: 1.8ms preprocess, 195.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 7 motorcycles, 2 buss, 2 trucks, 199.7ms
# Speed: 1.6ms preprocess, 199.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 motorcycles, 2 buss, 3 trucks, 194.4ms
# Speed: 2.0ms preprocess, 194.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 2 trucks, 191.9ms
# Speed: 1.7ms preprocess, 191.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 motorcycles, 2 buss, 2 trucks, 197.6ms
# Speed: 1.7ms preprocess, 197.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 motorcycles, 3 buss, 1 truck, 196.8ms
# Speed: 1.1ms preprocess, 196.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
